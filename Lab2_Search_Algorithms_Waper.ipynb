# %% [markdown]
# <a href="https://colab.research.google.com/github/http-hades/FUNDAI-Laboratories-WAPER/blob/main/Lab2_Search_Algorithms_Waper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 2: Maze Solving Using BFS, DFS, and A* Search
#
# ## Fundamentals of Artificial Intelligence
#
# **Name:** [Jan Andrie C. Waper]
# **Course:** [BSCS-AI 2a]
# **Section:** [09282 FUNDAI]
# **Date:** [August 24, 2026]
#
# **GitHub URL:**
#
# ## Description
# This laboratory implements BFS, DFS, and A* Search to solve a maze.
# The search results are visualized using matplotlib.
